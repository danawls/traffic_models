# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/its-돌발/1/its_e_1_1.csv', on_bad_lines='skip')

# %%
df
# Out:
#                      돌발일시    관리기관    도로타입 도로번호         도로명     방향  돌발구분  \
# 0     2023-01-01 13:12:27  한국도로공사    고속국도   60       서울양양선  양양 방향  기타돌발
# 1     2023-01-01 12:41:17  한국도로공사    고속국도   45       중부내륙선  창원 방향  기타돌발
# 2     2023-01-01 11:05:13  한국도로공사    고속국도   65  동해선(부산-포항)  포항 방향  교통사고
# 3     2023-01-01 15:48:21  한국도로공사    고속국도   40       평택제천선  제천 방향  기타돌발
# 4     2023-01-01 14:13:00  한국도로공사    고속국도   25       논산천안선  천안 방향  기타돌발
# ...                   ...     ...     ...  ...         ...    ...   ...
# 1126  2023-01-01 15:04:00     경찰청     시군도    0        가양대로      -    공사
# 1127  2023-01-01 15:12:00     경찰청    일반국도   38        서동대로      -    공사
# 1128  2023-01-01 15:22:00     경찰청  특별광역시도    0   계백로1716번길      -    공사
# 1129  2023-01-01 16:19:00     경찰청  특별광역시도    0        국회대로      -  교통사고
# 1130  2023-01-01 18:56:00     경찰청    고속국도   30    당진영덕고속도로      -  교통사고
#
#        돌발상세구분                                               돌발내용           X  \
# 0          고장                                       (갓길)승용차고장처리중    128.4929
# 1     차량증가/정체                                            차량증가/정체    127.6062
# 2          사고                                     (갓길)승용차관련사고처리중    129.4162
# 3     차량증가/정체                                            차량증가/정체    127.6166
# 4     차량증가/정체                                   -차령터널(263K)3km정체    127.1026
# ...       ...                                                ...         ...
# 1126        -           <공사> 가양로 구룡사거리 마포구고양시덕양구 1차로 주의운전 도로공사 -  126.872128
# 1127        -        <공사> 일반국도38호선 안양교앞교차로 내리사거리 2차로 주의운전 도로공사 -  127.215717
# 1128        -   <공사> 계백로1716번길 센트럴파크3차 글꽃초등학교사거리 1차로 주의운전 도로공사 -  127.411943
# 1129        -     <사고> 국회대로 여의2교남단교차로 의원회관앞교차로 4차로 주의운전 교통사고 서울청  126.912093
# 1130        -  <사고> 청주영덕고속도로 안동시의성군 안동JC 2차로 156 Km (안동JC 방향)...  128.630014
#
#               Y       링크아이디               돌발종료일시
# 0       37.9769  2650168000                    -
# 1       37.2134  2370601900                    -
# 2       35.7734  3520264800                    -
# 3       36.9861  2810051300                    -
# 4       36.0819           -                    -
# ...         ...         ...                  ...
# 1126  37.581869  2180147300  2023-01-01 18:00:00
# 1127  37.009206  2310014402  2023-01-01 17:00:00
# 1128  36.319642  1840126300  2023-01-01 18:00:00
# 1129  37.526136  1180031502  2023-01-01 16:30:00
# 1130  36.431557  3540811600  2023-01-01 19:26:00
#
# [1131 rows x 13 columns]

# %%
df
# Out:
#                      돌발일시    관리기관    도로타입 도로번호         도로명     방향  돌발구분  \
# 0     2023-01-01 13:12:27  한국도로공사    고속국도   60       서울양양선  양양 방향  기타돌발
# 1     2023-01-01 12:41:17  한국도로공사    고속국도   45       중부내륙선  창원 방향  기타돌발
# 2     2023-01-01 11:05:13  한국도로공사    고속국도   65  동해선(부산-포항)  포항 방향  교통사고
# 3     2023-01-01 15:48:21  한국도로공사    고속국도   40       평택제천선  제천 방향  기타돌발
# 4     2023-01-01 14:13:00  한국도로공사    고속국도   25       논산천안선  천안 방향  기타돌발
# ...                   ...     ...     ...  ...         ...    ...   ...
# 1126  2023-01-01 15:04:00     경찰청     시군도    0        가양대로      -    공사
# 1127  2023-01-01 15:12:00     경찰청    일반국도   38        서동대로      -    공사
# 1128  2023-01-01 15:22:00     경찰청  특별광역시도    0   계백로1716번길      -    공사
# 1129  2023-01-01 16:19:00     경찰청  특별광역시도    0        국회대로      -  교통사고
# 1130  2023-01-01 18:56:00     경찰청    고속국도   30    당진영덕고속도로      -  교통사고
#
#        돌발상세구분                                               돌발내용           X  \
# 0          고장                                       (갓길)승용차고장처리중    128.4929
# 1     차량증가/정체                                            차량증가/정체    127.6062
# 2          사고                                     (갓길)승용차관련사고처리중    129.4162
# 3     차량증가/정체                                            차량증가/정체    127.6166
# 4     차량증가/정체                                   -차령터널(263K)3km정체    127.1026
# ...       ...                                                ...         ...
# 1126        -           <공사> 가양로 구룡사거리 마포구고양시덕양구 1차로 주의운전 도로공사 -  126.872128
# 1127        -        <공사> 일반국도38호선 안양교앞교차로 내리사거리 2차로 주의운전 도로공사 -  127.215717
# 1128        -   <공사> 계백로1716번길 센트럴파크3차 글꽃초등학교사거리 1차로 주의운전 도로공사 -  127.411943
# 1129        -     <사고> 국회대로 여의2교남단교차로 의원회관앞교차로 4차로 주의운전 교통사고 서울청  126.912093
# 1130        -  <사고> 청주영덕고속도로 안동시의성군 안동JC 2차로 156 Km (안동JC 방향)...  128.630014
#
#               Y       링크아이디               돌발종료일시
# 0       37.9769  2650168000                    -
# 1       37.2134  2370601900                    -
# 2       35.7734  3520264800                    -
# 3       36.9861  2810051300                    -
# 4       36.0819           -                    -
# ...         ...         ...                  ...
# 1126  37.581869  2180147300  2023-01-01 18:00:00
# 1127  37.009206  2310014402  2023-01-01 17:00:00
# 1128  36.319642  1840126300  2023-01-01 18:00:00
# 1129  37.526136  1180031502  2023-01-01 16:30:00
# 1130  36.431557  3540811600  2023-01-01 19:26:00
#
# [1131 rows x 13 columns]

# %%
df['돌발구분'].unique()
# Out:
# array(['기타돌발', '교통사고', '재난', '기상', '공사', '기타', nan], dtype=object)

# %% [markdown]
# ## 결측치 분석(시각화)

# %%
import missingno as msno
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 폰트 설정 (예: 'Malgun Gothic' 또는 'AppleGothic' 등)
font_path = '/System/Library/Fonts/AppleSDGothicNeo.ttc'  # Windows의 경우, Mac에서는 '/System/Library/Fonts/AppleGothic.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 유니코드 마이너스 설정 (마이너스 기호 깨짐 방지)
plt.rcParams['axes.unicode_minus'] = False

# missingno 시각화 예시
msno.matrix(df)
plt.show()
