# %%
import pandas as pd
import dask.dataframe as ddf

# %%
df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/표준노드링크/data/node.csv', dtype='object')

# %%
df
# Out:
#            NODE_ID NODE_TYPE         NODE_NAME TURN_P UPDATEDATE REMARK  \
# 0       3690003600       101    ¿Ö°üÃ»³âÈ¸ÀÇ¼Ò      1   20230519    NaN
# 1       3690004304       101  ¿Ö°üÁß¾ÓÃÊµîÇÐ±³      1   20230519    NaN
# 2       3690004601       101       ¼®Àü¸®806-7      1   20230519    NaN
# 3       3690005000       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 4       3690011100       101      ÇØ¼Ö¾î¸°ÀÌÁý      0   20230519    NaN
# ...            ...       ...               ...    ...        ...    ...
# 206111  3680175100       101         ¿¹»ê¸®927      0   20230519    NaN
# 206112  3680179500       101        ´ë»ê¸®1044      0   20230519    NaN
# 206113  3680181600       102     ÀÛÀº¸®»ê190-1      0   20230519    NaN
# 206114  3690001100       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 206115  3690001500       101          ¿µ¸®1084      0   20230519    NaN
#
#        HIST_TYPE HISTREMARK                                       geometry
# ...

# %%
mdf = ddf.read_csv('/Volumes/Expansion/traffic-prediction/data/표준노드링크/data/node.csv')

# %%
mdf
# Out:
# Dask DataFrame Structure:
#               NODE_ID NODE_TYPE NODE_NAME TURN_P UPDATEDATE   REMARK HIST_TYPE HISTREMARK geometry
# npartitions=1
#                 int64     int64    string  int64      int64  float64   float64    float64   string
#                   ...       ...       ...    ...        ...      ...       ...        ...      ...
# Dask Name: read_csv, 1 expression
# Expr=ReadCSV(0cd986a)

# %%
df.astype({'NODE_NAME':'string'})
# Out:
#            NODE_ID NODE_TYPE         NODE_NAME TURN_P UPDATEDATE REMARK  \
# 0       3690003600       101    ¿Ö°üÃ»³âÈ¸ÀÇ¼Ò      1   20230519    NaN
# 1       3690004304       101  ¿Ö°üÁß¾ÓÃÊµîÇÐ±³      1   20230519    NaN
# 2       3690004601       101       ¼®Àü¸®806-7      1   20230519    NaN
# 3       3690005000       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 4       3690011100       101      ÇØ¼Ö¾î¸°ÀÌÁý      0   20230519    NaN
# ...            ...       ...               ...    ...        ...    ...
# 206111  3680175100       101         ¿¹»ê¸®927      0   20230519    NaN
# 206112  3680179500       101        ´ë»ê¸®1044      0   20230519    NaN
# 206113  3680181600       102     ÀÛÀº¸®»ê190-1      0   20230519    NaN
# 206114  3690001100       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 206115  3690001500       101          ¿µ¸®1084      0   20230519    NaN
#
#        HIST_TYPE HISTREMARK                                       geometry
# ...

# %%
df['NODE_NAME']
# Out:
# 0           ¿Ö°üÃ»³âÈ¸ÀÇ¼Ò
# 1         ¿Ö°üÁß¾ÓÃÊµîÇÐ±³
# 2              ¼®Àü¸®806-7
# 3               ¼Ó¼ºº¯È­Á¡
# 4             ÇØ¼Ö¾î¸°ÀÌÁý
#                 ...
# 206111           ¿¹»ê¸®927
# 206112          ´ë»ê¸®1044
# 206113       ÀÛÀº¸®»ê190-1
# 206114          ¼Ó¼ºº¯È­Á¡
# 206115            ¿µ¸®1084
# Name: NODE_NAME, Length: 206116, dtype: object

# %%
mmdf = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/표준노드링크/node_other.csv', encoding='utf-8', dtype='object')

# %%
mmdf
# Out:
#            NODE_ID NODE_TYPE         NODE_NAME TURN_P UPDATEDATE REMARK  \
# 0       3690003600       101    ¿Ö°üÃ»³âÈ¸ÀÇ¼Ò      1   20230519    NaN
# 1       3690004304       101  ¿Ö°üÁß¾ÓÃÊµîÇÐ±³      1   20230519    NaN
# 2       3690004601       101       ¼®Àü¸®806-7      1   20230519    NaN
# 3       3690005000       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 4       3690011100       101      ÇØ¼Ö¾î¸°ÀÌÁý      0   20230519    NaN
# ...            ...       ...               ...    ...        ...    ...
# 206111  3680175100       101         ¿¹»ê¸®927      0   20230519    NaN
# 206112  3680179500       101        ´ë»ê¸®1044      0   20230519    NaN
# 206113  3680181600       102     ÀÛÀº¸®»ê190-1      0   20230519    NaN
# 206114  3690001100       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 206115  3690001500       101          ¿µ¸®1084      0   20230519    NaN
#
#        HIST_TYPE HISTREMARK                                       geometry
# ...

# %%
df
# Out:
#            NODE_ID NODE_TYPE         NODE_NAME TURN_P UPDATEDATE REMARK  \
# 0       3690003600       101    ¿Ö°üÃ»³âÈ¸ÀÇ¼Ò      1   20230519    NaN
# 1       3690004304       101  ¿Ö°üÁß¾ÓÃÊµîÇÐ±³      1   20230519    NaN
# 2       3690004601       101       ¼®Àü¸®806-7      1   20230519    NaN
# 3       3690005000       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 4       3690011100       101      ÇØ¼Ö¾î¸°ÀÌÁý      0   20230519    NaN
# ...            ...       ...               ...    ...        ...    ...
# 206111  3680175100       101         ¿¹»ê¸®927      0   20230519    NaN
# 206112  3680179500       101        ´ë»ê¸®1044      0   20230519    NaN
# 206113  3680181600       102     ÀÛÀº¸®»ê190-1      0   20230519    NaN
# 206114  3690001100       103        ¼Ó¼ºº¯È­Á¡      0   20230519    NaN
# 206115  3690001500       101          ¿µ¸®1084      0   20230519    NaN
#
#        HIST_TYPE HISTREMARK                                       geometry
# ...

# %%
import missingno as msn

# %%
msn.matrix(df)
# Out:
# <Axes: >

# %%
df.drop(['REMARK', 'HIST_TYPE', 'HISTREMARK'], axis=1, inplace=True)

# %%
df
# Out:
#            NODE_ID NODE_TYPE         NODE_NAME TURN_P UPDATEDATE  \
# 0       3690003600       101    ¿Ö°üÃ»³âÈ¸ÀÇ¼Ò      1   20230519
# 1       3690004304       101  ¿Ö°üÁß¾ÓÃÊµîÇÐ±³      1   20230519
# 2       3690004601       101       ¼®Àü¸®806-7      1   20230519
# 3       3690005000       103        ¼Ó¼ºº¯È­Á¡      0   20230519
# 4       3690011100       101      ÇØ¼Ö¾î¸°ÀÌÁý      0   20230519
# ...            ...       ...               ...    ...        ...
# 206111  3680175100       101         ¿¹»ê¸®927      0   20230519
# 206112  3680179500       101        ´ë»ê¸®1044      0   20230519
# 206113  3680181600       102     ÀÛÀº¸®»ê190-1      0   20230519
# 206114  3690001100       103        ¼Ó¼ºº¯È­Á¡      0   20230519
# 206115  3690001500       101          ¿µ¸®1084      0   20230519
#
#                                              geometry
# 0        POINT (128.40143291923889 35.98756183745635)
# 1        POINT (128.40517889519722 35.99951853267461)
# ...

# %%
df.to_csv('/Volumes/Expansion/traffic-prediction/data/표준노드링크/data/node_m1.csv', index=False)
