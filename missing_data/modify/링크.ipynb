# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/표준노드링크/data/link.csv', on_bad_lines='skip')

# %%
df
# Out:
#            LINK_ID      F_NODE      T_NODE  LANES  ROAD_RANK  ROAD_TYPE  \
# 0       2710002605  2710246000  2710245800      2        101          0
# 1       2710002506  2710246300  2710008400      2        101          0
# 2       2710002607  2710246200  2710246000      2        101          0
# 3       2710706900  2710245000  2710244600      2        107          0
# 4       2150268601  2150102800  2150102900      1        107          0
# ...            ...         ...         ...    ...        ...        ...
# 548649  2870019411  2870008101  2870078400      2        101          0
# 548650  3130000103  3130000101  3130000106      1        106          0
# 548651  3510029708  3510012607  3510015403      1        105          0
# 548652  1860014904  1860006902  1860007000      1        104          0
# 548653  2650003820  2650001502  2650001501      1        106          0
#
#        ROAD_NO       ROAD_NAME  ROAD_USE  MULTI_LINK  ...  REST_VEH  REST_W  \
# ...

# %%
df.drop(['REMARK', 'HIST_TYPE', 'HISTREMARK'], axis=1, inplace=True)

# %%
df
# Out:
#            LINK_ID      F_NODE      T_NODE  LANES  ROAD_RANK  ROAD_TYPE  \
# 0       2710002605  2710246000  2710245800      2        101          0
# 1       2710002506  2710246300  2710008400      2        101          0
# 2       2710002607  2710246200  2710246000      2        101          0
# 3       2710706900  2710245000  2710244600      2        107          0
# 4       2150268601  2150102800  2150102900      1        107          0
# ...            ...         ...         ...    ...        ...        ...
# 548588  2870019411  2870008101  2870078400      2        101          0
# 548589  3130000103  3130000101  3130000106      1        106          0
# 548590  3510029708  3510012607  3510015403      1        105          0
# 548591  1860014904  1860006902  1860007000      1        104          0
# 548592  2650003820  2650001502  2650001501      1        106          0
#
#        ROAD_NO       ROAD_NAME  ROAD_USE  MULTI_LINK  CONNECT  MAX_SPD  \
# ...

# %%
df.isnull().sum()
# Out:
# LINK_ID       0
# F_NODE        0
# T_NODE        0
# LANES         0
# ROAD_RANK     0
# ROAD_TYPE     0
# ROAD_NO       0
# ROAD_NAME     0
# ROAD_USE      0
# MULTI_LINK    0
# CONNECT       0
# MAX_SPD       0
# REST_VEH      0
# REST_W        0
# REST_H        0
# C-ITS         0
# LENGTH        0
# UPDATEDATE    0
# geometry      0
# dtype: int64

# %%
df.to_csv('/Volumes/Expansion/traffic-prediction/data/표준노드링크/data/link_m1.csv', index=False)

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >
