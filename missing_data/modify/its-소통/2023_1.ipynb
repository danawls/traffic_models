# %%
import pandas as pd
import numpy as np
import dask.dataframe as ddf

# %%
# 데이터 로드
for i in range(31):
    globals()[f'its_c_1_{i}_dask'] = ddf.read_csv(f'/Volumes/Expansion/traffic-prediction/data/its-소통/1/its_c_1_{i + 1}.csv', dtype='object')
    for partition in globals()[f'its_c_1_{i}_dask'].to_delayed():
        globals()[f'its_c_1_{i}'] = globals()[f'its_c_1_{i}'] + partition.compute()

# %%
its_c_1_0.isnull().sum()
# Out:
# 20230101            0
# 0000                0
# 1000000100          0
# Unnamed: 3    1379890
# 35                  0
# 0                   0
# dtype: int64

# %%
its_c_1_0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1616869 entries, 0 to 1616868
# Data columns (total 6 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   20230101    1616869 non-null  object
#  1   0000        1616869 non-null  object
#  2   1000000100  1616869 non-null  object
#  3   Unnamed: 3  236979 non-null   object
#  4   35          1616869 non-null  object
#  5   0           1616869 non-null  object
# dtypes: object(6)
# memory usage: 74.0+ MB

# %%
for i in range(31):
    globals()[f'its_c_1_{i}'].columns = ['생성일', '생성시분', '링크ID', '도로관리기관', '통행속도', '통행시간']

# %%
its_c_1_0
# Out:
#               생성일  생성시분        링크ID 도로관리기관  통행속도 통행시간
# 0        20230101  2345  2510159608    NaN    26    0
# 1        20230101  2345  2510159700    NaN  25.5    0
# 2        20230101  2345  2510159800    NaN    21    0
# 3        20230101  2345  2510159900    NaN    31    0
# 4        20230101  2345  2510159901    NaN  20.5    0
# ...           ...   ...         ...    ...   ...  ...
# 1616864  20230101  2355  4180383901    NaN     4    0
# 1616865  20230101  2355  4180384001    NaN    97    0
# 1616866  20230101  2355  4180384101    NaN    76    0
# 1616867  20230101  2355  4180384201    NaN   115    0
# 1616868  20230101  2355  4180384301    NaN    79    0
#
# [1616869 rows x 6 columns]

# %%
# 유의 변수만 남기기
for i in range(31):
    globals()[f'its_c_1_{i}'].drop('도로관리기관', axis = 1, inplace=True)

# %%
for i in range(31):
    print(globals()[f'its_c_1_{i}'].isnull().sum())
# Out:
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    2
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# 링크ID    0
# 통행속도    0
# 통행시간    0
# dtype: int64
# 생성일     0
# 생성시분    0
# ...

# %% [markdown]
# # 결과: 결측치 없음
