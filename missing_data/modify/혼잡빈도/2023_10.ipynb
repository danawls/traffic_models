# %%
import pandas as pd

df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_10.csv', encoding='cp949')

# %%
df.drop('Unnamed: 13', axis=1, inplace=True)

# %%
df
# Out:
#            집계년월   집계시분        VDS_ID 기점종점방향구분코드  노선번호   지점이정  도로이정  평균교통량  \
# 0        202310  01:50  0100VDE05100          E   100  52.90  52.1      0
# 1        202310  01:50  0100VDE05300          E   100  54.70  52.1      3
# 2        202310  01:50  0100VDE05300          E   100  54.70  52.1      6
# 3        202310  01:50  0100VDE05500          E   100  56.40  52.1      0
# 4        202310  01:50  0100VDE05500          E   100  56.40  52.1      0
# ...         ...    ...           ...        ...   ...    ...   ...    ...
# 5478683  202310  23:55  6000VDS03300          S  6000  43.39  48.8     12
# 5478684  202310  23:55  6000VDS03400          S  6000  45.16  48.8      7
# 5478685  202310  23:55  6000VDS03400          S  6000  45.16  48.8     11
# 5478686  202310  23:55  6000VDS03500          S  6000  47.41  48.8      7
# 5478687  202310  23:55  6000VDS03500          S  6000  47.41  48.8     12
#
#            평균속도  혼잡빈도수  차로번호          콘존명  콘존길이
# ...

# %%
df.to_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_10_m1.csv', index=False)
