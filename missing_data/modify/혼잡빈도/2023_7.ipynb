# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_7.csv', encoding='cp949')

# %%
df.drop('Unnamed: 13', axis=1, inplace=True)

# %%
df
# Out:
#            집계년월   집계시분        VDS_ID 기점종점방향구분코드  노선번호   지점이정   도로이정  평균교통량  \
# 0        202307  00:00  0010VDE00100          E    10   1.40   0.20      5
# 1        202307  00:00  0010VDE00100          E    10   1.40   0.20     15
# 2        202307  00:00  0010VDE00100          E    10   1.40   0.20      8
# 3        202307  00:00  0010VDE00200          E    10   2.40   2.02      6
# 4        202307  00:00  0010VDE00200          E    10   2.40   2.02     16
# ...         ...    ...           ...        ...   ...    ...    ...    ...
# 5463567  202307  23:55  6000VDS03300          S  6000  43.39  48.80     13
# 5463568  202307  23:55  6000VDS03400          S  6000  45.16  48.80      9
# 5463569  202307  23:55  6000VDS03400          S  6000  45.16  48.80     12
# 5463570  202307  23:55  6000VDS03500          S  6000  47.41  48.80      8
# 5463571  202307  23:55  6000VDS03500          S  6000  47.41  48.80     11
#
#            평균속도  혼잡빈도수  차로번호          콘존명  콘존길이
# ...

# %%
df.to_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_7_m1.csv', index=False)
