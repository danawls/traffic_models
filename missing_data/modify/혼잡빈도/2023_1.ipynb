# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_1.csv', encoding='cp949')

# %%
df
# Out:
#            집계년월   집계시분        VDS_ID 기점종점방향구분코드  노선번호    지점이정   도로이정  평균교통량  \
# 0        202301  01:50  0100VDS13000          S   100  154.40  156.0      7
# 1        202301  01:50  0100VDS13000          S   100  154.40  156.0      5
# 2        202301  01:50  0100VDS13100          S   100  155.40  156.0      3
# 3        202301  01:50  0100VDS13100          S   100  155.40  156.0      7
# 4        202301  01:50  0100VDS13100          S   100  155.40  156.0      4
# ...         ...    ...           ...        ...   ...     ...    ...    ...
# 5482597  202301  23:55  6000VDS03300          S  6000   43.39   48.8     11
# 5482598  202301  23:55  6000VDS03400          S  6000   45.16   48.8      6
# 5482599  202301  23:55  6000VDS03400          S  6000   45.16   48.8     10
# 5482600  202301  23:55  6000VDS03500          S  6000   47.41   48.8      6
# 5482601  202301  23:55  6000VDS03500          S  6000   47.41   48.8     10
#
# ...

# %%
df.drop('Unnamed: 13', axis=1, inplace=True)

# %%
df
# Out:
#            집계년월   집계시분        VDS_ID 기점종점방향구분코드  노선번호    지점이정   도로이정  평균교통량  \
# 0        202301  01:50  0100VDS13000          S   100  154.40  156.0      7
# 1        202301  01:50  0100VDS13000          S   100  154.40  156.0      5
# 2        202301  01:50  0100VDS13100          S   100  155.40  156.0      3
# 3        202301  01:50  0100VDS13100          S   100  155.40  156.0      7
# 4        202301  01:50  0100VDS13100          S   100  155.40  156.0      4
# ...         ...    ...           ...        ...   ...     ...    ...    ...
# 5482597  202301  23:55  6000VDS03300          S  6000   43.39   48.8     11
# 5482598  202301  23:55  6000VDS03400          S  6000   45.16   48.8      6
# 5482599  202301  23:55  6000VDS03400          S  6000   45.16   48.8     10
# 5482600  202301  23:55  6000VDS03500          S  6000   47.41   48.8      6
# 5482601  202301  23:55  6000VDS03500          S  6000   47.41   48.8     10
#
#            평균속도  혼잡빈도수  차로번호          콘존명  콘존길이
# ...

# %%
df.to_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_1_m1.csv', index=False)
