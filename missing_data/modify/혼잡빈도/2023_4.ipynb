# %%
import pandas as pd

df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_4.csv', encoding='cp949')

# %%
df
# Out:
#            집계년월   집계시분        VDS_ID 기점종점방향구분코드  노선번호    지점이정    도로이정  평균교통량  \
# 0        202304  01:50  0010VDS31680          S    10  410.80  416.05     32
# 1        202304  01:50  0010VDS31680          S    10  410.80  416.05     23
# 2        202304  01:50  0010VDS31680          S    10  410.80  416.05     27
# 3        202304  01:50  0010VDS31680          S    10  410.80  416.05     19
# 4        202304  01:50  0010VDS31700          S    10  411.40  416.05     13
# ...         ...    ...           ...        ...   ...     ...     ...    ...
# 5456703  202304  23:55  6000VDS03300          S  6000   43.39   48.80     12
# 5456704  202304  23:55  6000VDS03400          S  6000   45.16   48.80      7
# 5456705  202304  23:55  6000VDS03400          S  6000   45.16   48.80     11
# 5456706  202304  23:55  6000VDS03500          S  6000   47.41   48.80      7
# 5456707  202304  23:55  6000VDS03500          S  6000   47.41   48.80     11
#
# ...

# %%
df.drop('Unnamed: 13', axis=1, inplace=True)

# %%
df.to_csv('/Volumes/Expansion/traffic-prediction/data/혼잡빈도/confusion_4_m1.csv', index=False)
