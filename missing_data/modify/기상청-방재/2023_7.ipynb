# %%
import pandas as pd
from sklearn.impute import KNNImputer

# %%
df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_7.csv', encoding='CP949')

# %%
path = '/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_7.csv'
df = pd.read_csv(path, encoding='CP949')
# 숫자형 열만 선택 (열 이름이 정확한지 확인)
numeric_columns = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '현지기압(hPa)', '해면기압(hPa)', '습도(%)']

# KNN Imputer 생성 (k=2로 설정)
imputer = KNNImputer(n_neighbors=3)

# 결측치 대체 수행
df_imputed = imputer.fit_transform(df.loc[:, numeric_columns])

# 대체된 값을 DataFrame으로 변환
df_imputed = pd.DataFrame(df_imputed, columns=numeric_columns)

# 원본 데이터프레임에 대체된 열을 다시 삽입
df[numeric_columns] = df_imputed

df.to_csv('/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_7_m1.csv', index=False)
del df

# %%
mdf = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_7_m1.csv')

# %%
mdf
# Out:
#          지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  \
# 0        12  안면도(감)  2023-07-01 00:00    22.0     37.4      1.8      0.0
# 1        12  안면도(감)  2023-07-01 01:00    22.0    282.5      1.0      0.0
# 2        12  안면도(감)  2023-07-01 02:00    21.4      0.0      0.4      0.0
# 3        12  안면도(감)  2023-07-01 03:00    21.8     19.5      2.0      0.0
# 4        12  안면도(감)  2023-07-01 04:00    21.6     53.2      2.0      0.0
# ...     ...     ...               ...     ...      ...      ...      ...
# 380521  994      심포  2023-07-30 20:00    26.1    350.6      1.3      4.0
# 380522  994      심포  2023-07-30 21:00    26.2     33.5      3.9      0.0
# 380523  994      심포  2023-07-30 22:00    25.6     96.8      2.1      0.0
# 380524  994      심포  2023-07-30 23:00    25.2    136.3      2.0      0.0
# 380525  994      심포  2023-07-31 00:00    24.7    106.7      2.1      0.0
#
#         현지기압(hPa)  해면기압(hPa)  습도(%)
# 0           997.0     1003.9   95.0
# ...
