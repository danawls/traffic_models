# %%
import pandas as pd

# %%
df = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_1.csv', encoding='CP949')

# %%
df
# Out:
#          지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  \
# 0        12  안면도(감)  2023-01-01 00:00     4.5    301.6      0.8      0.0
# 1        12  안면도(감)  2023-01-01 01:00     4.0     77.3      0.7      0.0
# 2        12  안면도(감)  2023-01-01 02:00     4.1     47.7      1.1      0.0
# 3        12  안면도(감)  2023-01-01 03:00     4.0      0.0      0.2      0.0
# 4        12  안면도(감)  2023-01-01 04:00     4.0      0.0      0.4      0.0
# ...     ...     ...               ...     ...      ...      ...      ...
# 381469  994      심포  2023-01-30 20:00    -0.1    273.3      2.7      0.0
# 381470  994      심포  2023-01-30 21:00     0.3    247.1      3.4      0.0
# 381471  994      심포  2023-01-30 22:00     0.1    219.9      1.6      0.0
# 381472  994      심포  2023-01-30 23:00    -3.3    145.1      2.9      0.0
# 381473  994      심포  2023-01-31 00:00    -3.6    138.3      2.3      0.0
#
#         현지기압(hPa)  해면기압(hPa)  습도(%)
# 0          1023.5     1031.0   52.0
# 1          1023.2     1030.7   55.0
# 2          1023.1     1030.6   58.0
# 3          1023.2     1030.7   60.0
# 4          1022.7     1030.2   62.0
# ...           ...        ...    ...
# 381469     1023.7     1024.1   64.0
# 381470     1024.0     1024.4   67.0
# 381471     1024.1     1024.5   63.0
# 381472     1023.6     1024.0   77.0
# 381473     1023.7     1024.1   80.0
#
# [381474 rows x 10 columns]

# %%
import missingno as msno

# %%
import missingno as msno
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# 폰트 설정 (예: 'Malgun Gothic' 또는 'AppleGothic' 등)
font_path = '/System/Library/Fonts/AppleSDGothicNeo.ttc'  # Windows의 경우, Mac에서는 '/System/Library/Fonts/AppleGothic.ttf'
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# 유니코드 마이너스 설정 (마이너스 기호 깨짐 방지)
plt.rcParams['axes.unicode_minus'] = False

# missingno 시각화 예시
msno.matrix(df)
plt.show()

# %%
msno.heatmap(df)
# Out:
# <Axes: >

# %%
msno.dendrogram(df)
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
from sklearn.impute import KNNImputer

# %%
df
# Out:
#          지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  \
# 0        12  안면도(감)  2023-01-01 00:00     4.5    301.6      0.8      0.0
# 1        12  안면도(감)  2023-01-01 01:00     4.0     77.3      0.7      0.0
# 2        12  안면도(감)  2023-01-01 02:00     4.1     47.7      1.1      0.0
# 3        12  안면도(감)  2023-01-01 03:00     4.0      0.0      0.2      0.0
# 4        12  안면도(감)  2023-01-01 04:00     4.0      0.0      0.4      0.0
# ...     ...     ...               ...     ...      ...      ...      ...
# 381469  994      심포  2023-01-30 20:00    -0.1    273.3      2.7      0.0
# 381470  994      심포  2023-01-30 21:00     0.3    247.1      3.4      0.0
# 381471  994      심포  2023-01-30 22:00     0.1    219.9      1.6      0.0
# 381472  994      심포  2023-01-30 23:00    -3.3    145.1      2.9      0.0
# 381473  994      심포  2023-01-31 00:00    -3.6    138.3      2.3      0.0
#
#         현지기압(hPa)  해면기압(hPa)  습도(%)
# 0          1023.5     1031.0   52.0
# 1          1023.2     1030.7   55.0
# 2          1023.1     1030.6   58.0
# 3          1023.2     1030.7   60.0
# 4          1022.7     1030.2   62.0
# ...           ...        ...    ...
# 381469     1023.7     1024.1   64.0
# 381470     1024.0     1024.4   67.0
# 381471     1024.1     1024.5   63.0
# 381472     1023.6     1024.0   77.0
# 381473     1023.7     1024.1   80.0
#
# [381474 rows x 10 columns]

# %%
df.isnull()
# Out:
#            지점    지점명     일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  현지기압(hPa)  \
# 0       False  False  False   False    False    False    False      False
# 1       False  False  False   False    False    False    False      False
# 2       False  False  False   False    False    False    False      False
# 3       False  False  False   False    False    False    False      False
# 4       False  False  False   False    False    False    False      False
# ...       ...    ...    ...     ...      ...      ...      ...        ...
# 381469  False  False  False   False    False    False    False      False
# 381470  False  False  False   False    False    False    False      False
# 381471  False  False  False   False    False    False    False      False
# 381472  False  False  False   False    False    False    False      False
# 381473  False  False  False   False    False    False    False      False
#
#         해면기압(hPa)  습도(%)
# 0           False  False
# 1           False  False
# 2           False  False
# 3           False  False
# 4           False  False
# ...           ...    ...
# 381469      False  False
# 381470      False  False
# 381471      False  False
# 381472      False  False
# 381473      False  False
#
# [381474 rows x 10 columns]

# %%
# 숫자형 열만 선택 (열 이름이 정확한지 확인)
numeric_columns = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '현지기압(hPa)', '해면기압(hPa)', '습도(%)']

# KNN Imputer 생성 (k=2로 설정)
imputer = KNNImputer(n_neighbors=2)

# 결측치 대체 수행
df_imputed = imputer.fit_transform(df.loc[:, numeric_columns])

# 대체된 값을 DataFrame으로 변환
df_imputed = pd.DataFrame(df_imputed, columns=numeric_columns)

# 원본 데이터프레임에 대체된 열을 다시 삽입
df[numeric_columns] = df_imputed

print(df)
# Out:
#          지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  강수량(mm)  \
# 0        12  안면도(감)  2023-01-01 00:00     4.5    301.6      0.8      0.0
# 1        12  안면도(감)  2023-01-01 01:00     4.0     77.3      0.7      0.0
# 2        12  안면도(감)  2023-01-01 02:00     4.1     47.7      1.1      0.0
# 3        12  안면도(감)  2023-01-01 03:00     4.0      0.0      0.2      0.0
# 4        12  안면도(감)  2023-01-01 04:00     4.0      0.0      0.4      0.0
# ...     ...     ...               ...     ...      ...      ...      ...
# 381469  994      심포  2023-01-30 20:00    -0.1    273.3      2.7      0.0
# 381470  994      심포  2023-01-30 21:00     0.3    247.1      3.4      0.0
# 381471  994      심포  2023-01-30 22:00     0.1    219.9      1.6      0.0
# 381472  994      심포  2023-01-30 23:00    -3.3    145.1      2.9      0.0
# 381473  994      심포  2023-01-31 00:00    -3.6    138.3      2.3      0.0
#
#         현지기압(hPa)  해면기압(hPa)  습도(%)
# 0          1023.5     1031.0   52.0
# 1          1023.2     1030.7   55.0
# 2          1023.1     1030.6   58.0
# 3          1023.2     1030.7   60.0
# 4          1022.7     1030.2   62.0
# ...           ...        ...    ...
# 381469     1023.7     1024.1   64.0
# 381470     1024.0     1024.4   67.0
# 381471     1024.1     1024.5   63.0
# 381472     1023.6     1024.0   77.0
# 381473     1023.7     1024.1   80.0
#
# [381474 rows x 10 columns]

# %% [markdown]
# # 결측치 보정 진행

# %%
path = '/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_1.csv'
df = pd.read_csv(path, encoding='CP949')
# 숫자형 열만 선택 (열 이름이 정확한지 확인)
numeric_columns = ['기온(°C)', '풍향(deg)', '풍속(m/s)', '강수량(mm)', '현지기압(hPa)', '해면기압(hPa)', '습도(%)']

# KNN Imputer 생성 (k=2로 설정)
imputer = KNNImputer(n_neighbors=3)

# 결측치 대체 수행
df_imputed = imputer.fit_transform(df.loc[:, numeric_columns])

# 대체된 값을 DataFrame으로 변환
df_imputed = pd.DataFrame(df_imputed, columns=numeric_columns)

# 원본 데이터프레임에 대체된 열을 다시 삽입
df[numeric_columns] = df_imputed

df.to_csv('/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_1_m1.csv')
del df

# %%
mdf = pd.read_csv('/Volumes/Expansion/traffic-prediction/data/기상청-방재/weather_1_m1.csv')

# %%
mdf
# Out:
#         Unnamed: 0   지점     지점명                일시  기온(°C)  풍향(deg)  풍속(m/s)  \
# 0                0   12  안면도(감)  2023-01-01 00:00     4.5    301.6      0.8
# 1                1   12  안면도(감)  2023-01-01 01:00     4.0     77.3      0.7
# 2                2   12  안면도(감)  2023-01-01 02:00     4.1     47.7      1.1
# 3                3   12  안면도(감)  2023-01-01 03:00     4.0      0.0      0.2
# 4                4   12  안면도(감)  2023-01-01 04:00     4.0      0.0      0.4
# ...            ...  ...     ...               ...     ...      ...      ...
# 381469      381469  994      심포  2023-01-30 20:00    -0.1    273.3      2.7
# 381470      381470  994      심포  2023-01-30 21:00     0.3    247.1      3.4
# 381471      381471  994      심포  2023-01-30 22:00     0.1    219.9      1.6
# 381472      381472  994      심포  2023-01-30 23:00    -3.3    145.1      2.9
# 381473      381473  994      심포  2023-01-31 00:00    -3.6    138.3      2.3
#
#         강수량(mm)  현지기압(hPa)  해면기압(hPa)  습도(%)
# 0           0.0     1023.5     1031.0   52.0
# 1           0.0     1023.2     1030.7   55.0
# 2           0.0     1023.1     1030.6   58.0
# 3           0.0     1023.2     1030.7   60.0
# 4           0.0     1022.7     1030.2   62.0
# ...         ...        ...        ...    ...
# 381469      0.0     1023.7     1024.1   64.0
# 381470      0.0     1024.0     1024.4   67.0
# 381471      0.0     1024.1     1024.5   63.0
# 381472      0.0     1023.6     1024.0   77.0
# 381473      0.0     1023.7     1024.1   80.0
#
# [381474 rows x 11 columns]
